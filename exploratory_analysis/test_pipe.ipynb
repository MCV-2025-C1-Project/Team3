# %%
import pickle
from pathlib import Path

pkl_path = Path("../results/qst1_w4/method1/result.pkl")

with open(pkl_path, "rb") as f:
    results = pickle.load(f)

for i, r in enumerate(results[:]):  # mostrar los primeros 5 resultados
    print(f"\n🔹 Imagen {i}:")
    print(r)
# Out:
# 🔹 Imagen 0:
# [[223, 271, 270, 269, 268, 267, 266, 265, 264, 263], [-1]]
#
# 🔹 Imagen 1:
# [[35, 209, 106, 88, 271, 270, 269, 268, 267, 266]]
#
# 🔹 Imagen 2:
# [[203, 204, 271, 270, 269, 268, 267, 266, 265, 264], [211, 199, 118, 102, 271, 270, 269, 268, 267, 266]]
#
# 🔹 Imagen 3:
# [[272, 145, 75, 271, 270, 269, 268, 267, 266, 265], [117, 277, 20, 18, 197, 207, 165, 222, 114, 67]]
#
# 🔹 Imagen 4:
# [[-1]]
#
# 🔹 Imagen 5:
# [[-1]]
#
# 🔹 Imagen 6:
# [[-1]]
#
# 🔹 Imagen 7:
# [[-1]]
#
# 🔹 Imagen 8:
# [[150, 204, 123, 95, 271, 270, 269, 268, 267, 266]]
#
# 🔹 Imagen 9:
# [[258, 271, 270, 269, 268, 267, 266, 265, 264, 263], [35, 283, 88, 70, 272, 271, 270, 269, 268, 267]]
#
# 🔹 Imagen 10:
# [[-1], [252, 271, 270, 269, 268, 267, 266, 265, 264, 263]]
#
# 🔹 Imagen 11:
# [[-1]]
#
# 🔹 Imagen 12:
# [[62, 271, 270, 269, 268, 267, 266, 265, 264, 263], [-1]]
#
# 🔹 Imagen 13:
# [[-1]]
#
# 🔹 Imagen 14:
# [[222, 277, 209, 145, 117, 85, 13, 272, 271, 270]]
#
# 🔹 Imagen 15:
# [[-1]]
#
# 🔹 Imagen 16:
# ...

# %%
results
# Out:
# [[[223, 271, 270, 269, 268, 267, 266, 265, 264, 263]],
#  [[35, 209, 106, 88, 271, 270, 269, 268, 267, 266]],
#  [[203, 204, 271, 270, 269, 268, 267, 266, 265, 264],
#   [211, 199, 118, 102, 271, 270, 269, 268, 267, 266]],
#  [[117, 272, 109, 282, 258, 276, 145, 277, 206, 84]],
#  [[-1]],
#  [[-1]],
#  [[-1]],
#  [[-1]],
#  [[150, 204, 123, 95, 271, 270, 269, 268, 267, 266]],
#  [[258, 271, 270, 269, 268, 267, 266, 265, 264, 263],
#   [35, 283, 88, 70, 272, 271, 270, 269, 268, 267]],
#  [[252, 182, 271, 270, 269, 268, 267, 266, 265, 264]],
#  [[-1]],
#  [[62, 38, 141, 271, 270, 269, 268, 267, 266, 265]],
#  [[-1]],
#  [[222, 277, 209, 145, 117, 85, 13, 272, 271, 270]],
#  [[-1]],
#  [[94, 70, 245, 255, 175, 181, 82, 8, 271, 270],
#   [132, 189, 100, 271, 270, 269, 268, 267, 266, 265]],
#  [[-1]],
#  [[-1]],
#  [[-1]],
#  [[-1], [280, 272, 271, 270, 269, 268, 267, 266, 265, 264]],
#  [[251, 242, 204, 102, 38, 263, 271, 270, 269, 268]],
# ...
